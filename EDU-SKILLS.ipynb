# %% [markdown]
# <a href="https://colab.research.google.com/github/DEEPAK-RAMGIRI/AIML-LAB/blob/main/EDU-SKILLS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDU - SKILLS

# %% [markdown]
# # Basics

# %%
import tensorflow
import numpy as np
from tensorflow import keras

# %%
Model = keras.Sequential([keras.layers.Dense(units = 1,input_shape=[1])])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
Model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
Model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - loss: 102.2088
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 80.4232
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 63.2831
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 49.7979
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 39.1882
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 30.8408
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 24.2733
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 19.1061
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 15.0406
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 11.8419
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 9.3251
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.3449
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 5.7867
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.5607
# Epoch 15/500
# ...

# %%
array = np.array([10.0])
print((Model.predict(array),1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# (array([[30.99621]], dtype=float32), 1)

# %% [markdown]
# # INTRODUCTION

# %%
import tensorflow as tf

# %%
print("Version of Current tensorflow is:",tf.__version__)
# Out:
# Version of Current tensorflow is: 2.17.1

# %%
# here we are importing Fashion MNIST data. Which is available in the keras dataset
mnist = tf.keras.datasets.fashion_mnist
